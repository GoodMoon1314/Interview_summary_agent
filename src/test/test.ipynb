# %%
list = ["1","3","5"]

del list[0]

print(list)
# Out:
# ['3', '5']

# %%
del list[0]

print(list)
# Out:
# ['5']

# %%
del list[0]

print(list)
# Out:
# []

# %%
del list[0]

print(list)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 del list[0]
#       2
#       3 print(list)
#
# IndexError: list assignment index out of range
